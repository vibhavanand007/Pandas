# %%
import pandas as pd

# %%
df = pd.read_csv(r"V:\Data Science\data Analyst\Python\Pandas\chapter_3_assets\1_intro\movies.csv")
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (1.9, 9.3, 7.919444444444445)

# %%
df_bolly = df[df.industry=='Bollywood']
df_holly = df[df.industry=='Hollywood']

# %%
df_bolly.reset_index(inplace=True, col_level=1)

# %%
df_bolly = df_bolly.drop(columns='level_0')

# %%
df_bolly
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 1   Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 2                      3 Idiots  Bollywood          2009          8.4
# 3      Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 4              Bajirao Mastani   Bollywood          2015          7.2
# 5              Taare Zameen Par  Bollywood          2007          8.3
# 6           Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 7                            PK  Bollywood          2014          8.1
# 8                         Sanju  Bollywood          2018          NaN
# 9             The Kashmir Files  Bollywood          2022          8.3
# 10            Bajrangi Bhaijaan  Bollywood          2015          8.1
# 11                       Race 3  Bollywood          2018          1.9
# ...

# %%
df_holly
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# 12                                The Godfather  Hollywood          1972
# ...

# %%
print('Bollywood Movies imbd_ratings: ',round(df_bolly['imdb_rating'].mean(),2))
print('Hollywood Movies imbd_ratings: ',round(df_holly['imdb_rating'].mean(),2))
print('All Over Movies imbd_ratings : ',round(df['imdb_rating'].mean(),2))
# Out:
# Bollywood Movies imbd_ratings:  7.66
# Hollywood Movies imbd_ratings:  8.13
# All Over Movies imbd_ratings :  7.92
